# %% [markdown]
# # INRIA ASSIGNEMENT

# %% [markdown]
# Le but de ce devoir est dans un premier temps la détection et la suppression d'entrées doublons dans une base de données puis dans un second temps l'exploration et la visualiation des données fournis

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('sqlite:///data.db', echo=False)
con = engine.connect()
df_patient = pd.read_sql('select * from patient', con=con)
df_pcr = pd.read_sql('select * from test', con=con)
con.close()

# %% [markdown]
# Deux bases de données sont fournis : ***df_patient*** et ***df_pcr***.

# %%
df_patient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 12 columns):
# patient_id       20000 non-null int64
# given_name       19560 non-null object
# surname          19575 non-null object
# street_number    19618 non-null float64
# address_1        19204 non-null object
# suburb           19788 non-null object
# postcode         19801 non-null object
# state            18010 non-null object
# date_of_birth    17989 non-null float64
# age              16003 non-null float64
# phone_number     19081 non-null object
# address_2        7893 non-null object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 1.8+ MB

# %%
df_patient.head(5)
# Out:
#    patient_id given_name    surname  street_number            address_1  \
# 0      221958    matisse     clarke           13.0          rene street
# 1      771155     joshua     elrick           23.0         andrea place
# 2      231932      alice     conboy           35.0     mountain circuit
# 3      465838     sienna   craswell           39.0  cumberlegeicrescent
# 4      359178     joshua  bastiaans          144.0        lowrie street
#
#           suburb postcode state  date_of_birth   age phone_number address_2
# 0     ellenbrook     2527    wa     19710708.0  32.0  08 86018809  westella
# 1   east preston     2074   nsw     19120921.0  34.0  02 97793152   foxdown
# 2       prospect     2305   nsw     19810905.0  22.0  02 20403934      None
# 3          henty     3620    wa     19840809.0  30.0  02 62832318    jodane
# 4  campbell town     4051   nsw     19340430.0  31.0  03 69359594      None

# %%
df_pcr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8800 entries, 0 to 8799
# Data columns (total 2 columns):
# patient_id    8800 non-null int64
# pcr           8800 non-null object
# dtypes: int64(1), object(1)
# memory usage: 137.6+ KB

# %%
df_pcr.head(5)
# Out:
#    patient_id       pcr
# 0      653091         N
# 1      347667  Negative
# 2      708481  Positive
# 3      148825  Negative
# 4      150081  Negative

# %% [markdown]
# La première base de données est un dataframe contenant des entrées de patients (id,nom,prénoms,adresse,code postal). Certaines colonnes contiennent des entrées nulles.
# La seconde contient des id de patients avec les résultats au test PCR. Elle ne contient pas d'entrées nulles
#
# On va donc commencer par "nettoyer" les deux dataframes.

# %% [markdown]
# ## 1. Nettoyage du dataframe : ***df_patient***

# %%
df_patient.dtypes
# Out:
# patient_id         int64
# given_name        object
# surname           object
# street_number    float64
# address_1         object
# suburb            object
# postcode          object
# state             object
# date_of_birth    float64
# age              float64
# phone_number      object
# address_2         object
# dtype: object

# %% [markdown]
# <a id='incoherence_donnees'></a>
# On regarde tout d'abord la qualité/fiabilité des données fournis. Cela passe notamment par les types des différentes colonnes d'entrées.
# - ***Patient ID*** : Le numéro ID d'un patient, normalement doit être unique, est en général de type entier. Ce qui est le cas ici
# - ***given_name*** : Le prénom officiel du patient est une string donc categorical donc a bien comme *dtype* un objet. De même pour surname; adress_1,adress_2,suburb,state.
#
# - ***phone_number*** : Le numéro de téléphone, peut contenir une extension correspondant à un état ou un espace donc il est préférable de le laisser en string
#
# - ***date_of_birth*** : Les dates de naissances des patients pourraient être sous type Timestamp ou au mieux sous forme de int64, de même pour l'âge et le numéro de rue.
#
# - ***postcode***  : Le code postal est un nombre allant de 3 à 4 chiffres devrait être sous type int64 et non une categorical value. De plus les states fournis ne correspondent pas aux codes postaux

# %%
df_patient.describe()
# Out:
#           patient_id  street_number  date_of_birth           age
# count   20000.000000   19618.000000   1.798900e+04  16003.000000
# mean   553918.938750      98.812468   1.949638e+07     27.534337
# std    260234.961111    2481.908686   2.926916e+05      7.807008
# min    100005.000000       0.000000   1.290041e+07      0.000000
# 25%    330194.250000      10.000000   1.924113e+07     24.000000
# 50%    556327.500000      24.000000   1.950032e+07     29.000000
# 75%    779419.500000      60.000000   1.975052e+07     33.000000
# max    999993.000000  342951.000000   1.999123e+07     92.000000

# %% [markdown]
# D'un point de vue statistique, on constate des valeurs NULL pour les numéros de *rues, dob et l'âge*. Pour la date de naissance on remarque une date de naissance minimale à 1290. Enfin si on compare la moyenne d'âge avec l'âge médian on trouve une différence de 2ans.

# %%
df_patient["age"].median()
# Out:
# 29.0

# %%
len(df_patient["patient_id"].unique()) #Find how many uniques values in patient_id column
# Out:
# 19798

# %% [markdown]
# On a 19798 ID de patients distincts au lieu de 20000, or l'ID de patient pour un hôpital est supposée être unique. Cela peut être dû soit à des doublons, soit les données regroupées dans cette base proviennent de différents hôpitaux qui ont chacun leur système numérique unique.

# %%
patient_id_dupes = list(df_patient["patient_id"].duplicated()) #Find the duplicates values in the patient_id column
patient_id_dupes_idx = [i for i in range(len(patient_id_dupes)) if patient_id_dupes[i]==True] #Retrieve their index

# %%
df_patient.loc[df_patient["patient_id"] == df_patient.loc[patient_id_dupes_idx[0],"patient_id"]]
# Out:
#       patient_id given_name      surname  street_number           address_1  \
# 1456      119816        jed      rollins           63.0      mauldon street
# 2377      119816        sam  iasenzaniro           12.0  booroondara street
#
#                 suburb postcode state  date_of_birth  age phone_number  \
# 1456  macquarie fields     4169   nsw     19010805.0  NaN  07 73786737
# 2377          brighton     6153    sa     19621207.0  NaN  03 90915909
#
#      address_2
# 1456      None
# 2377      None

# %% [markdown]
# Ces deux patients ont le même ID mais sont deux personnes différentes. On peut en conclure que l'ID de patient n'est pas un critère pour identifier un doublons dans notre base de données.

# %%
df_patient.describe(include='object')
# Out:
#        given_name surname          address_1     suburb postcode  state  \
# count       19560   19575              19204      19788    19801  18010
# unique       1171    4273               4326       2925     2021    102
# top        emiily   white  paul coe crescent  toowoomba     4350    nsw
# freq          373     539                 57        167       96   6143
#
#        phone_number       address_2
# count         19081            7893
# unique        17916            3460
# top     02 97010866  brentwood vlge
# freq              4              85

# %% [markdown]
# Pour les données non numériques, on remarque pour les états qu'on a 102 valeurs, or seule 10 états existent en Australie.

# %% [markdown]
# On va donc procéder la manière suivante pour le nettoyage de données :
# <br>
# <br>
#     A) Remplissage des valeurs NULL pour les colonnes ***given_name, surname, adress_1, address_2, suburb, phone_number***.
#     Les données de ces colonnes non fournis ne peuvent être corrigés autrement.
#     <br>
#     <br>
#     B) Correction des dates de naissances et âges
#     <br>
#     <br>
#     C) Correction des codes postaux et des états

# %% [markdown]
# ## A) Remplissage

# %%
#We work on a instance copy of the dataframe, thus any modifications we can always keep the original one without
#reloading it again
df_dedup = df_patient.copy()

# %%
df_dedup["given_name"]=df_dedup['given_name'].fillna('None')
df_dedup["surname"]=df_dedup['surname'].fillna('None')
df_dedup["address_1"]=df_dedup['address_1'].fillna('None')
df_dedup["address_2"]=df_dedup['address_2'].fillna('None')
df_dedup["phone_number"]=df_dedup['phone_number'].fillna(0)
df_dedup["street_number"]=df_dedup['street_number'].fillna(0)

# %%
df_dedup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 12 columns):
# patient_id       20000 non-null int64
# given_name       20000 non-null object
# surname          20000 non-null object
# street_number    20000 non-null float64
# address_1        20000 non-null object
# suburb           19788 non-null object
# postcode         19801 non-null object
# state            18010 non-null object
# date_of_birth    17989 non-null float64
# age              16003 non-null float64
# phone_number     20000 non-null object
# address_2        20000 non-null object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 1.8+ MB

# %% [markdown]
# ## B) Correction de colonnes
# ### Etats et codes postaux

# %% [markdown]
# Comme on l'a souligné auparavant des [incohérences](#incoherence_donnees) apparraissent dans la correspondance des codes postaux et des états. L'Australie est composé de 8 états ayant chacun un intervalle de données et une abbréviation spécifique.
# ***

# %% [markdown]
# - __Exemple:__
# <br>
# <br>
# ***Premier cas :**
# On prend une entrée dans la liste au hasard. Le postcode écrit est *2428* ce qui correspond au state **NSW** or le state écrit est **QLD**.
# ***Second cas :**
# On prend une entrée dans la liste au hasard. Le state écrit est *vc* ce qui correspond à aucun state  officiellement mais se rapproche du state  **VIC**.

# %%
print(" First Example : ")
print(df_dedup.iloc[15,6:8])
print("  ")
print(" Second Example : ")
print("  ")
print(df_dedup.iloc[301,6:8])
# Out:
#  First Example :
# postcode    2428
# state        qld
# Name: 15, dtype: object
#
#  Second Example :
#
# postcode    4574
# state         vc
# Name: 301, dtype: object

# %% [markdown]
# Pour mettre à jours nos deux colonnes on effectue le procédé suivant :
#
# 1. On commence par vérifier les valeurs NaN dans notre colonne **Postcode** ainsi que les entrées ne correspondant pas à un postcode.On fait pareillement pour les states. On leur assigne une valeur nulle.
#
# 2. On définis un dictionnaire des states avec l'intervalle dans lequel le postcode correspondant se trouve. Pour les postcodes non nulles on assigne les bon states à partir de notre dictionnaire.
#
# 3. Pour les postocdes nulles on vérifie si un state est fournis. Dans le cas où le state est fournis on assigne le postcode correspondant. Dans le cas où le state n'est pas fournis, on peut vérifier à partir du suburb : https://jumpshare.com/v/V8Cu6szjbgAzdcMXWfw9# (des BDD sont disponibles sur internet).
#
# 4. Dans le cas où ni le state, ni le postcode ni le surburb n'est fournis, il est préférable de drop l'entrée car le but étant d'étudier la prévalence du COVID en fonction des zones géographiques cet entrée ne sera pas utilisable. *(on constatera par la suite que nous n'arriverons pas à cet étape là, tout les suburb, postcodes et states sont disponibles dans notre dataframe)*

# %%
#Create two new column to update our postcode and state and keep the original to compare
df_dedup["postcode_updated"]=df_dedup["postcode"]
df_dedup["state_updated"]=df_dedup["state"]
df_dedup["suburb_updated"]=df_dedup["suburb"]

# %%
#List of index of NULL postcode and state
index_null_postcode = df_dedup[df_dedup['postcode'].isnull()].index.tolist()
index_null_state=df_patient[df_patient['state'].isnull()].index.tolist()

# %%
#We create a new column to find index of postcode who are different than digits 
df_dedup["postcode_str"]=df_dedup["postcode"].astype(str)
odd_postcode=[i for i in range(len(df_dedup["postcode_str"])) if len(df_dedup.loc[i,"postcode_str"])>4]

# %%
print(df_dedup.iloc[odd_postcode[0],5:8])
# Out:
# suburb                      3023
# postcode    port noarlunga south
# state                        tas
# Name: 3976, dtype: object

# %% [markdown]
# Le postcode fournis est en réalité une banlieue en Australie situé en Australie du Sud soit un code postale entre 5000 et 6000 or le code postal fournis ici est 3023 correspondant à l'état Victoria.
# On fait donc le choix de ne garder pour ces cas là que le state fournis
# <a id='suburb'></a>

# %%
#Because all the entry in are swapped we swapped them:
for i in odd_postcode:
    df_dedup.loc[i,"suburb_updated"]=df_dedup.loc[i,"postcode"]
    df_dedup.loc[i,"postcode_updated"]=df_dedup.loc[i,"suburb"]

# %%
#Verify that all the suburbs are updated 
for i in odd_postcode:
    print(df_dedup.loc[i,"suburb_updated"])
# Out:
# port noarlunga south
# naremburn
# toowoobma
# brighton
# oraneg
# blacktown
# forest hill
# port lincoln
# ashfield
# forest hill
# toowoomba
# regents park
# kelmscott
# donnybrook

# %%
#We check every postcode assigned is 3-4 digits
odd_postcode_verif=[i for i in odd_postcode if len(df_dedup.loc[i,"postcode_updated"])>4]
odd_postcode_verif
# Out:
# [9718]

# %%
df_dedup.loc[9718,"postcode_updated"]
# Out:
# '467l0'

# %%
df_dedup.loc[9718,"postcode_updated"]=0

# %%
#We assign the rest the zero value

for i in index_null_postcode:
    df_dedup.loc[i,"postcode_updated"]=0
for i in index_null_state:
    df_dedup.loc[i,"state_updated"]=0

# %%
df_dedup["postcode_updated"]=df_dedup["postcode_updated"].astype(int)
df_dedup.dtypes
# Out:
# patient_id            int64
# given_name           object
# surname              object
# street_number       float64
# address_1            object
# suburb               object
# postcode             object
# state                object
# date_of_birth       float64
# age                 float64
# phone_number         object
# address_2            object
# postcode_updated      int64
# state_updated        object
# suburb_updated       object
# postcode_str         object
# dtype: object

# %%
#We create two dictionnaries one for the mapping from postcode to states, the other one from states to postcode
postal_codes = dict([(i,"nt") for i in range(800,900)]+
                    [(i,"nsw") for i in range(1000,1999)]+
                    [(i,"nsw") for i in range(2000,2600)]+
                    [(i,"nsw") for i in range(2619,2900)]+
                    [(i,"act") for i in range(2600,2619)]+
                    [(i,"act") for i in range(2900,2921)]+
                    [(i,"nsw") for i in range(2921,3000)]+
                    [(i,"vic") for i in range(3000,4000)]+
                    [(i,"qld") for i in range(4000,5000)]+
                    [(i,"sa") for i in range(5000,5800)]+
                    [(i,"wa") for i in range(6000,6800)]+
                    [(i,"tas") for i in range(7000,7800)]
                   )
state_codes ={"nt":800,"nsw":1000,"act":2600,"vic":3000,"qld":4000,"sa":5000,"wa":6000,"tas":7000}
#For the state to postcode we assign the first value of the postcode range

# %%
#First case we update the state based on the non-null postcode
idx_not_null_postcode = [i for i in range(df_dedup.shape[0]) if df_dedup.loc[i,"postcode_updated"]!=0]

# %%
#Mapping the states to the dictionnary postal_codes
for i in idx_not_null_postcode:
    df_dedup.loc[i,"state_updated"]=postal_codes[df_dedup.loc[i,"postcode_updated"]]

# %%
#Verify
df_dedup.iloc[:5,5:]
# Out:
#           suburb postcode state  date_of_birth   age phone_number address_2  \
# 0     ellenbrook     2527    wa     19710708.0  32.0  08 86018809  westella
# 1   east preston     2074   nsw     19120921.0  34.0  02 97793152   foxdown
# 2       prospect     2305   nsw     19810905.0  22.0  02 20403934      None
# 3          henty     3620    wa     19840809.0  30.0  02 62832318    jodane
# 4  campbell town     4051   nsw     19340430.0  31.0  03 69359594      None
#
#    postcode_updated state_updated suburb_updated postcode_str
# 0              2527           nsw     ellenbrook         2527
# 1              2074           nsw   east preston         2074
# 2              2305           nsw       prospect         2305
# 3              3620           vic          henty         3620
# 4              4051           qld  campbell town         4051

# %%
#Second case we update the null postcode based on the non-null state
idx_state_not_null=[]
for i in range(df_dedup.shape[0]):
    if df_dedup.loc[i,"state_updated"]!=0 and i not in idx_not_null_postcode:
        idx_state_not_null.append(i)

# %%
for i in idx_state_not_null:

    df_dedup.loc[i,"postcode_updated"]=state_codes[df_dedup.loc[i,"state_updated"]]

# %%
#Verify
df_dedup.iloc[95:100,5:]
# Out:
#          suburb postcode state  date_of_birth   age phone_number  \
# 95    coombabah     None   vic     19351020.0  26.0  03 90265874
# 96   palmerston     4069    wa     19451003.0   NaN  04 65877742
# 97  harris park     3658   vic     19330804.0  21.0  02 04698047
# 98   burringbar     7330    wa            NaN  36.0  03 94670748
# 99     labrador     2782  None     19710301.0  30.0  04 83500862
#
#                address_2  postcode_updated state_updated suburb_updated  \
# 95            hazel hill              3000           vic      coombabah
# 96                  None              4069           qld     palmerston
# 97  ainslie nursing home              3658           vic    harris park
# 98              moorilla              7330           tas     burringbar
# 99                tongul              2782           nsw       labrador
#
#    postcode_str
# 95         None
# 96         4069
# 97         3658
# 98         7330
# 99         2782

# %%
#Final case : the state and postcode of the entry is a null value
state_postcode_null = []
for i in range(df_dedup.shape[0]):
    if df_dedup.loc[i,"state_updated"]==0 and df_dedup.loc[i,"postcode_updated"]==0:
        state_postcode_null.append(i)

# %%
print("We have {} rows with no postcode and state".format(len(state_postcode_null)))
# Out:
# We have 17 rows with no postcode and state

# %%
#Like before we look at the suburbs
sb_list = [df_dedup.loc[i,"suburb"] for i in state_postcode_null]
set(sb_list)
# Out:
# {'alexandra bridge',
#  'casino',
#  'dapto',
#  'downer',
#  'elwood',
#  'greenacre',
#  'kings cross',
#  'lake illawarra',
#  'lower templestowe',
#  'morven',
#  'ngunnawal',
#  'northmead',
#  'salisbury',
#  'wagaman',
#  'winchelsea south',
#  'winston hills',
#  'yarrawonga'}

# %%
#The length of the set corresponds to the length of the suburbs list, all suburbs are unique.
#Because the list of the length is short we make a dictionnary
suburb_to_postcode = {"downer":2602,"wagaman":800,"kings cross":1340,"lake illawarra":2528,
                          "elwood":3184,
                          "greenacre":2190,
                          "salisbury":5108,
                          "northmead":2152,
                          "yarrawonga":3730,
                          "lower templestowe":3107,
                          "winston hills":2153,
                          "morven":4468,
                          "winchelsea south":3241,
                          "dapto":2530,
                          "alexandra bridge":6288,
                          "casino":2470,
                          "ngunnawal":2913}

# %%
#First we update the postcode from the suburb then the state from the postcode
for i in state_postcode_null:
    df_dedup.loc[i,"postcode_updated"]=suburb_to_postcode[df_dedup.loc[i,"suburb_updated"]]
    df_dedup.loc[i,"state_updated"]=postal_codes[df_dedup.loc[i,"postcode_updated"]]

# %%
df_dedup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
# patient_id          20000 non-null int64
# given_name          20000 non-null object
# surname             20000 non-null object
# street_number       20000 non-null float64
# address_1           20000 non-null object
# suburb              19788 non-null object
# postcode            19801 non-null object
# state               18010 non-null object
# date_of_birth       17989 non-null float64
# age                 16003 non-null float64
# phone_number        20000 non-null object
# address_2           20000 non-null object
# postcode_updated    20000 non-null int64
# state_updated       20000 non-null object
# suburb_updated      19788 non-null object
# postcode_str        20000 non-null object
# dtypes: float64(3), int64(2), object(11)
# memory usage: 2.4+ MB

# %%
#Finally we fill the null suburb with the string "None"
index_null_suburb = df_dedup[df_dedup['suburb'].isnull()].index.tolist()
for i in index_null_suburb:
    df_dedup.loc[i,"suburb_updated"]="None"

# %%
df_dedup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
# patient_id          20000 non-null int64
# given_name          20000 non-null object
# surname             20000 non-null object
# street_number       20000 non-null float64
# address_1           20000 non-null object
# suburb              19788 non-null object
# postcode            19801 non-null object
# state               18010 non-null object
# date_of_birth       17989 non-null float64
# age                 16003 non-null float64
# phone_number        20000 non-null object
# address_2           20000 non-null object
# postcode_updated    20000 non-null int64
# state_updated       20000 non-null object
# suburb_updated      20000 non-null object
# postcode_str        20000 non-null object
# dtypes: float64(3), int64(2), object(11)
# memory usage: 2.4+ MB

# %% [markdown]
# On peut maintenant passer à la correction des ages et date de naissances

# %% [markdown]
# ### Age et Date de naissance

# %%
df_dedup['dob_updated']= df_dedup["date_of_birth"]
df_dedup['age_updated']= df_dedup["age"]

# %%
index_null_dob = df_dedup[df_dedup['dob_updated'].isnull()].index.tolist()

# %%
index_null_age = df_dedup[df_dedup['age_updated'].isnull()].index.tolist()

# %%
df_dedup["age_updated"]=df_dedup["age_updated"].fillna(0) #valeurs null
df_dedup["dob_updated"]=df_dedup["dob_updated"].fillna(0) #valeurs

# %%
df_dedup['dob_updated']=df_dedup['dob_updated'].apply(lambda n: n if n%1 else int(n)) #remove trailling 0
df_dedup['age_updated']=df_dedup['age_updated'].apply(lambda n: n if n%1 else int(n)) #remove trailling 0

# %%
df_dedup["dob_updated"] = [(str(i)) for i in df_dedup["dob_updated"]]
df_dedup["dob_updated"] = [int(i[:4]) for i in df_dedup["dob_updated"]]

# %%
odd_year=df_dedup[(df_dedup["dob_updated"]<1900) & (df_dedup["dob_updated"]>0) ].index.tolist()

# %%
df_dedup.iloc[8882]
# Out:
# patient_id                          258272
# given_name                            jack
# surname                             jessup
# street_number                          509
# address_1                      stone place
# suburb                              batlow
# postcode                              None
# state                                  qld
# date_of_birth                  1.29004e+07
# age                                     34
# phone_number                   08 77804659
# address_2           mayflower retrmnt vlge
# postcode_updated                      4000
# state_updated                          qld
# suburb_updated                      batlow
# postcode_str                          None
# dob_updated                           1290
# age_updated                             34
# Name: 8882, dtype: object

# %%
df_dedup.loc[8882,"dob_updated"]=2020-df_dedup.loc[8882,"age_updated"]

# %%
dob_zero = [i for i in range(df_dedup.shape[0]) if df_dedup.loc[i,"dob_updated"]==0 ]
age_zero= [i for i in  range(df_dedup.shape[0] )if df_dedup.loc[i,"age_updated"] ==0 ]
age_dob_zero =[i for i in dob_zero if i  in age_zero]
for i in age_dob_zero:
    df_dedup.loc[i,"dob_updated"]=1950
    df_dedup.loc[i,"age_updated"]=70

# %%
dob_zero_not_age =[i for i in dob_zero if i not in age_zero]
for i in dob_zero_not_age:
    df_dedup.loc[i,"dob_updated"]=2020-df_dedup.loc[i,"age_updated"]

# %%
dob_zero_verif = [i for i in range(df_dedup.shape[0]) if df_dedup.loc[i,"dob_updated"]==0 ]
age_zero_verif= [i for i in  range(df_dedup.shape[0] )if df_dedup.loc[i,"age_updated"] ==0 ]

# %%
df_dedup["age_final"]=df_dedup["age_updated"]

# %%
for i in range(df_dedup.shape[0]):
    df_dedup.loc[i,"age_final"]=2020-df_dedup.loc[i,"dob_updated"]

# %%
#Verify
df_dedup.iloc[1]
# Out:
# patient_id                771155
# given_name                joshua
# surname                   elrick
# street_number                 23
# address_1           andrea place
# suburb              east preston
# postcode                    2074
# state                        nsw
# date_of_birth        1.91209e+07
# age                           34
# phone_number         02 97793152
# address_2                foxdown
# postcode_updated            2074
# state_updated                nsw
# suburb_updated      east preston
# postcode_str                2074
# dob_updated                 1912
# age_updated                   34
# age_final                    108
# Name: 1, dtype: object

# %%
cols_to_drop = ["suburb","postcode","state","date_of_birth","age","postcode_str","age_updated"]

# %%
df_dedup_clean = df_dedup.copy()

# %%
df_dedup_clean = df_dedup_clean.drop(["suburb","postcode","state","date_of_birth","age","postcode_str","age_updated"], axis = 1)

# %%
df_dedup_clean
# Out:
#        patient_id given_name      surname  street_number  \
# 0          221958    matisse       clarke           13.0
# 1          771155     joshua       elrick           23.0
# 2          231932      alice       conboy           35.0
# 3          465838     sienna     craswell           39.0
# 4          359178     joshua    bastiaans          144.0
# 5          744167         ky        laing          448.0
# 6          210268    matthew        laing           11.0
# 7          832180       jack      renfrey           27.0
# 8          154886      adele         ryan           76.0
# 9          237337   breeanne        wynne           12.0
# 10         621430    michael        white           17.0
# 11         187498       None        mason           20.0
# 12         999159     joshua      bristow           21.0
# 13         275203        max      godfrey          166.0
# 14         291335    mikayla     paterson           20.0
# 15         378167       cain      scarles           58.0
# 16         141090    georgia        white          117.0
# 17         429365       None       coffey         1409.0
# 18         164820        lia        wilde           30.0
# 19         887201   mitchekl  stephenskon           58.0
# 20         421879     callum      nicolle            2.0
# 21         818315       ruby      grafton           97.0
# 22         427069   mystique        white           85.0
# 23         876997        zac    rosendale            5.0
# 24         299041   harrison      neumann           60.0
# 25         891743    charlie     mcgregor           36.0
# 26         203355      clain      kinnane            3.0
# 27         335796       jake       clarke           66.0
# 28         314176      talia       mitton           10.0
# 29         284779  alexandra        miles           23.0
# ...           ...        ...          ...            ...
# 19970      489925     alicia     morrison            5.0
# 19971      186491   takeisha     rawlings           37.0
# 19972      144588      jamie     chandler          128.0
# 19973      301657   danielle      newport          611.0
# 19974      199152     connor        whait          563.0
# 19975      752160   ashleigh         None           30.0
# 19976      513727       kane     costigan            1.0
# 19977      896551      maxin         None            4.0
# 19978      438037   nicholas       jacura            6.0
# 19979      116167     thomas     matthews            6.0
# 19980      811863      ethan      statham           17.0
# 19981      210782       hana      barazda           18.0
# 19982      581005    rebecca        santi           13.0
# 19983      230775   victoria     whiteley           12.0
# 19984      134889     xavier       priest           28.0
# 19985      407822      sarah     matthews           58.0
# 19986      326406      kiara        cheel           89.0
# 19987      684550     robert   makovetsky            1.0
# 19988      235753       erin     jeffries            2.0
# 19989      704579    michael     eglinton          215.0
# 19990      690296     bayden          due         1084.0
# 19991      871835    william     villiers           20.0
# 19992      329489      amber  leeuwenburg           50.0
# 19993      506906     cooper     sherriff           25.0
# 19994      912344     fraser      mcneill           10.0
# 19995      368617       abby         None           19.0
# 19996      796658       dale       priest           19.0
# 19997      511885    alessia       mawlai            4.0
# 19998      985932     hannah        mason            1.0
# 19999      925217       jack      mcveigh            5.0
#
#                       address_1 phone_number                address_2  \
# 0                   rene street  08 86018809                 westella
# 1                  andrea place  02 97793152                  foxdown
# 2              mountain circuit  02 20403934                     None
# 3           cumberlegeicrescent  02 62832318                   jodane
# 4                 lowrie street  03 69359594                     None
# 5                   nyawi place  03 59872070                     None
# 6                  barnes place  02 86925029                     None
# 7                 osmand street  03 15575583              dhurringill
# 8                 house circuit  07 37444521                     None
# 9                 cowper street  08 24888117                     None
# 10                farrer street  08 61399758                     None
# 11               padbury street  03 85186450            pioneer lodge
# 12                  thake place  08 93848698                     None
# 13                givens street  07 88425978                     None
# 14        freda bennett circuit  08 88377793                     None
# 15                 reader court  03 67476384                   jorobe
# 16                burston place  07 53985196                     None
# 17                 musson close  03 13369308               silverweir
# 18                 elsey street  03 98048163                     None
# 19               rosman circuit  03 85151806                     None
# 20                 mcleod place  03 79802023                  marella
# 21               dannevig place  02 12194238               glenwarren
# 22             herington street  07 24234495                     None
# 23                harper street  03 34384419                     None
# 24           eggleston crescent  04 13196831                     None
# 25                bialla street  08 32766433                     None
# 26     alexander mackie circuit  07 49171625                     None
# 27              debenham street  04 99155978                     None
# 28               starling place  07 43440041        alexander's folly
# 29                 duffy street  02 24131074        riverland village
# ...                         ...          ...                      ...
# 19970                bibb place  04 00920566                     None
# 19971            brebner street  03 11566736                    botin
# 19972            rosman circuit  08 53766398              the willows
# 19973           ragless circuit  02 47073119                rosemount
# 19974           ebenezer street  07 30833018                     None
# 19975           winser crescent  04 10236954                glennhill
# 19976       stonehaven crescent  04 55808760                 townview
# 19977           stenhouse close  03 16942738  st john of god hospital
# 19978         bangalay crescent  04 47098663                     None
# 19979        biddlecombe street  03 95817460           brentwood vlge
# 19980        o'halloran circuit  07 56913484                     None
# 19981           hampton circuit  02 55468100                     None
# 19982            whistler place  07 06099570                     None
# 19983            beasley street  03 68108604                ponderosa
# 19984             needham place  02 74580410                     None
# 19985               zox circuit  08 77093884              lagoon farm
# 19986               shand place  02 90785400                  wiltona
# 19987            petterd street  03 60493727                     None
# 19988             bowling place  07 25650398                     None
# 19989         ambalindum street  02 85100697                     None
# 19990              weekes close  03 28550636                     None
# 19991               perry drive  08 24585653                     None
# 19992                      None  03 46144930                     None
# 19993           monaro crescent  04 36452619                     None
# 19994             collie street  02 77020191                     None
# 19995     john cleland crescent  02 92489054                 glenmore
# 19996     bellchambers crescent  07 20549476                     None
# 19997             miller street  03 83466737                     None
# 19998            halligan place  04 41125514                     None
# 19999              alinda place  07 52535106                     None
#
#        postcode_updated state_updated      suburb_updated  dob_updated  \
# 0                  2527           nsw          ellenbrook         1971
# 1                  2074           nsw        east preston         1912
# 2                  2305           nsw            prospect         1981
# 3                  3620           vic               henty         1984
# 4                  4051           qld       campbell town         1934
# 5                  3556           vic             barmera         1905
# 6                  2160           nsw           laurieton         1906
# 7                  2170           nsw         maribyrnong         1961
# 8                  2200           nsw            new farm         1943
# 9                  2062           nsw          bonnet bay         1903
# 10                 3971           vic      flagstaff hill         1983
# 11                 6239            wa           granville         1920
# 12                 7004           tas          oxley vale         1965
# 13                 4152           qld          leichhardt         1986
# 14                 4670           qld       dover heights         1981
# 15                 2428           nsw             dorrigo         1989
# 16                 4127           qld              conder         1992
# 17                 5019            sa  beaconsfield upper         1990
# 18                 3109           vic                None         1907
# 19                 2359           nsw            eastwood         1932
# 20                 2144           nsw             walgett         1934
# 21                 3180           vic            st clair         1918
# 22                 6000            wa       east maitland         1999
# 23                 6063            wa           mona vale         1929
# 24                 2560           nsw         tweed heads         1970
# 25                 2390           nsw         keysborough         1955
# 26                 5152            sa     north tamborine         1975
# 27                 4575           qld         sippy downs         1948
# 28                 2117           nsw         broken hill         1952
# 29                 2047           nsw     christies beach         1991
# ...                 ...           ...                 ...          ...
# 19970              6153            wa            st clair         1937
# 19971              2615           act                como         1903
# 19972              3355           vic           whitfield         1905
# 19973              3199           vic          graceville         1975
# 19974              3187           vic       mount gravatt         1938
# 19975              4806           qld          buff point         1984
# 19976              2203           nsw        shenton park         1910
# 19977              2117           nsw            goodwood         1901
# 19978              3850           vic            clarkson         1947
# 19979              4740           qld           unanderra         1920
# 19980              3350           vic       mount gravatt         1928
# 19981              2047           nsw                None         1973
# 19982              2452           nsw            artarmon         1915
# 19983              2388           nsw        landsborough         1949
# 19984              3318           vic            reynella         1950
# 19985              3174           vic         seven hills         1924
# 19986              2535           nsw           kincumber         1987
# 19987              3141           vic            parkdale         1940
# 19988              5038            sa            st kilda         1970
# 19989              2604           act  birmingham gardens         1914
# 19990              2068           nsw             allawah         1964
# 19991              3075           vic         mount annan         1942
# 19992              2578           nsw            glenwood         1972
# 19993              3149           vic            embleton         1921
# 19994              2075           nsw            booragul         1989
# 19995              2290           nsw        boyne island         1957
# 19996              3033           vic    hoppers crossing         1959
# 19997              3616           vic          smithfield         1994
# 19998              2443           nsw           beaumaris         1914
# 19999              4350           qld          thornlands         1923
#
#        age_final
# 0             49
# 1            108
# 2             39
# 3             36
# 4             86
# 5            115
# 6            114
# 7             59
# 8             77
# 9            117
# 10            37
# 11           100
# 12            55
# 13            34
# 14            39
# 15            31
# 16            28
# 17            30
# 18           113
# 19            88
# 20            86
# 21           102
# 22            21
# 23            91
# 24            50
# 25            65
# 26            45
# 27            72
# 28            68
# 29            29
# ...          ...
# 19970         83
# 19971        117
# 19972        115
# 19973         45
# 19974         82
# 19975         36
# 19976        110
# 19977        119
# 19978         73
# 19979        100
# 19980         92
# 19981         47
# 19982        105
# 19983         71
# 19984         70
# 19985         96
# 19986         33
# 19987         80
# 19988         50
# 19989        106
# 19990         56
# 19991         78
# 19992         48
# 19993         99
# 19994         31
# 19995         63
# 19996         61
# 19997         26
# 19998        106
# 19999         97
#
# [20000 rows x 12 columns]

# %%
df_dedup_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 12 columns):
# patient_id          20000 non-null int64
# given_name          20000 non-null object
# surname             20000 non-null object
# street_number       20000 non-null float64
# address_1           20000 non-null object
# phone_number        20000 non-null object
# address_2           20000 non-null object
# postcode_updated    20000 non-null int64
# state_updated       20000 non-null object
# suburb_updated      20000 non-null object
# dob_updated         20000 non-null int64
# age_final           20000 non-null int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 1.8+ MB

# %% [markdown]
# On fait le choix de garder ces colonnes pour nous permettre d'avoir un choix multiples en terme de critères de sélection pour la détection des doublons dans un dataframe.

# %%
#Export dataframe to csv
#df_dedup_clean.to_csv('df_dedup_clean.csv',index=False)

# %% [markdown]
# ## 1. Nettoyage du dataframe : ***df_pcr***

# %%
df_pcr.describe()
# Out:
#           patient_id
# count    8800.000000
# mean   554175.918977
# std    259491.959500
# min    100037.000000
# 25%    331553.000000
# 50%    556969.000000
# 75%    778063.750000
# max    999993.000000

# %%
print("On a donc {} ID de patients unique et {} doublons d'ID de patients".format(len(df_pcr["patient_id"].unique()),len(df_pcr)-len(df_pcr["patient_id"].unique())))
# Out:
# On a donc 8765 ID de patients unique et 35 doublons d'ID de patients

# %%
df_pcr[df_pcr.duplicated(keep=False)].sort_values(by="patient_id")
# Out:
#       patient_id       pcr
# 169       159500         N
# 2934      159500         N
# 1473      227192         N
# 8249      227192         N
# 3251      328071  Positive
# 4741      328071  Positive
# 4939      411955         N
# 3569      411955         N
# 1265      465871         N
# 7254      465871         N
# 7056      476826         N
# 6395      476826         N
# 6176      483152  Negative
# 5505      483152  Negative
# 2164      512755  Negative
# 5745      512755  Negative
# 4078      527530  Negative
# 4859      527530  Negative
# 4666      651216         N
# 3767      651216         N
# 224       655839  Negative
# 5071      655839  Negative
# 5724      670706  Positive
# 1790      670706  Positive
# 2251      728889  Negative
# 410       728889  Negative
# 7586      848423         N
# 8492      848423         N

# %% [markdown]
# Les 35 doublons d'ID de patients ont les même résultats PCR, on peut donc les supprimer.

# %%
df_pcr = df_pcr.drop_duplicates(keep=False)
df_pcr.sort_values(by="patient_id")
# Out:
#       patient_id       pcr
# 1900      100037         N
# 3919      100215  Negative
# 1733      100294         N
# 1672      100363         P
# 1880      100404         N
# 6336      100727  Negative
# 3699      100882  Positive
# 4592      100917  Negative
# 4703      101051  Negative
# 6005      101082  Positive
# 5869      101095  Negative
# 4707      101577         N
# 8079      101832  Negative
# 453       101845         N
# 5834      101917         N
# 7450      101919         P
# 6393      102016  Negative
# 3825      102159         N
# 8095      102187  Positive
# 724       102526         N
# 1579      102631         N
# 2470      102866  Positive
# 5593      102921         N
# 5646      103174  Negative
# 5343      103196         N
# 5460      103212         P
# 8794      103358         N
# 5649      103599         N
# 8693      103631  Negative
# 7202      103681  Positive
# ...          ...       ...
# 7640      997691  Negative
# 1724      997849         N
# 4649      997928  Positive
# 6758      998035  Positive
# 2268      998120  Negative
# 6738      998138         P
# 5363      998196  Negative
# 4567      998217         N
# 281       998320  Negative
# 5934      998332         N
# 3327      998342  Negative
# 1106      998407  Negative
# 8703      998436  Positive
# 8308      998607  Positive
# 440       998628         N
# 5478      998633  Positive
# 1626      998662  Negative
# 8412      998792  Negative
# 1361      998860  Negative
# 2255      998902  Positive
# 5669      999005  Positive
# 4259      999083  Negative
# 463       999084         N
# 3027      999159  Positive
# 7753      999434         N
# 8770      999482         N
# 3453      999497  Positive
# 8010      999573  Negative
# 8326      999885  Negative
# 1965      999993  Negative
#
# [8772 rows x 2 columns]

# %%
df_pcr.describe(include=['object'])
# Out:
#          pcr
# count   8772
# unique     4
# top        N
# freq    3468

# %% [markdown]
# Pour le résultat du PCR on a donc 4 valeurs possibles : Negative, Postive, N ou P. Ces 4 valeurs sont similaires on peut donc les uniformiser pour avoir uniquement Positive et Negative, la colonne PCR renvoyant une valeur soit True(Positive,1) soit False (Negative,0)

# %%
bool_pcr = {"Negative":False, "N":False, "Positive":True, "P":True}

# %%
df_pcr_clean = df_pcr.copy()

# %%
df_pcr_clean =df_pcr_clean.replace({"pcr":bool_pcr})

# %%
df_pcr_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8772 entries, 0 to 8799
# Data columns (total 2 columns):
# patient_id    8772 non-null int64
# pcr           8772 non-null bool
# dtypes: bool(1), int64(1)
# memory usage: 145.6 KB

# %%
df_pcr_clean.head(5)
# Out:
#    patient_id    pcr
# 0      653091  False
# 1      347667  False
# 2      708481   True
# 3      148825  False
# 4      150081  False

# %%
#Export dataframe to csv
#df_pcr_clean.to_csv('df_pcr_clean_final.csv',index=False)

# %%
#Merge two dataframe based on the patient ID key
df_patient_pcr = pd.merge(df_pcr_clean,df_dedup_clean,on="patient_id",how="inner")
#We want only the patient who were tested, so we only keep rows where the patient id value exists in both pcr and
#patient dataframe

# %%
df_patient_pcr
# Out:
#       patient_id    pcr given_name      surname  street_number  \
# 0         653091  False     daniel     campbell           58.0
# 1         347667  False  sebastian      mchenry           12.0
# 2         708481   True      sarah       rellos           20.0
# 3         148825  False      chloe       brammy          238.0
# 4         150081  False    charlie         None            6.0
# 5         876796  False  alexander        dixon           11.0
# 6         169224  False       kyle        eyles           79.0
# 7         755915   True      jamie      krollig           72.0
# 8         374486  False    rachael      wilkins           17.0
# 9         634003  False     lauren     braunack            2.0
# 10        918386  False    georgia      allanby           31.0
# 11        466326   True     sophie     schuster           36.0
# 12        605659  False     sophie      coleman           15.0
# 13        400572  False       jack    crosswell            3.0
# 14        631740  False     alexis      whillas           14.0
# 15        884141   True     taylah      collier          320.0
# 16        440459   True     bailey       hislop           19.0
# 17        130447  False  madeleine      seppelt          200.0
# 18        916386  False      corie         webb           91.0
# 19        317285  False     phoebe        sarah           21.0
# 20        982876  False      julia    humphreys           29.0
# 21        780215  False      dylan     shepherd           72.0
# 22        578366  False      james       tiller           18.0
# 23        651250   True      aidyn     fernando           26.0
# 24        781669   True  gabrielle          ang           16.0
# 25        455612  False     jordan      bartone            7.0
# 26        948689   True     claire         hand           46.0
# 27        988704  False    brayden         hope            1.0
# 28        455249  False       hudd       thomas           16.0
# 29        294243  False     marcus        green           41.0
# ...          ...    ...        ...          ...            ...
# 8882      667256   True       kane     shepherd          309.0
# 8883      589415  False       zali     cirvydas           21.0
# 8884      783889  False     annika       nguyen            9.0
# 8885      662080  False   ellouise         hope           70.0
# 8886      942549  False     philip     alderman           81.0
# 8887      313456  False  stephanie    muthukuda           42.0
# 8888      116375   True   isabella         None            6.0
# 8889      116375   True     emiily   piorkowski           12.0
# 8890      450500  False   mcgregor        abbey          105.0
# 8891      723944  False     hannah   pettingill           57.0
# 8892      682393  False        sam      coltman           51.0
# 8893      872592   True    juliana    poppleton            1.0
# 8894      618534  False    brinley      coulson            5.0
# 8895      580674  False   tanyshah         webb           34.0
# 8896      165488  False       None         hope          105.0
# 8897      714134  False      jaime     mcgregor           69.0
# 8898      541157   True    jacinta       feeley           29.0
# 8899      400589  False       ella       weetra           26.0
# 8900      375478  False       abby  smallacombe           62.0
# 8901      326884  False   angelica        dolan            6.0
# 8902      213604  False       lucy     matthews           14.0
# 8903      800336  False  alexandra       clarke           28.0
# 8904      270457  False       lily      jimenea           34.0
# 8905      658692  False      holly     dumbrell            1.0
# 8906      103358  False   nicholas     hingston          100.0
# 8907      249457  False    tiffany       loulps           31.0
# 8908      279689   True     daniel       excell           58.0
# 8909      975612  False    jessica       nguyen           10.0
# 8910      884429   True    chelsea      coltman           34.0
# 8911      272409  False      laura      maynard           40.0
#
#                   address_1 phone_number  \
# 0       sid barnes crescent  08 38772117
# 1         mundawari circuit  08 61083524
# 2             torres street  02 73197286
# 3           fitchett street  02 48826642
# 4               clark close  03 24096098
# 5                      None  04 21654709
# 6           longworth place            0
# 7     kingsford smith drive  08 03345937
# 8             kelsall place  08 50445222
# 9             lumeah street  08 76845890
# 10             sewell place  02 46350595
# 11         temperley street  07 15258839
# 12      sid barnes crescent  03 85340922
# 13          hughes crescent  07 60155245
# 14           gritten street  07 70663612
# 15             gamor street  07 88795287
# 16           wentcher place  03 48564288
# 17          dandenong court  02 46373117
# 18          collings street  07 83704242
# 19             gibbes place  04 95054398
# 20      sid barnes crescent  07 56171620
# 21             cradle close  04 14308700
# 22              arden place  08 89630544
# 23       eggleston crescent  04 59903074
# 24         narrabundah lane  08 63736128
# 25          blamey crescent  07 35972655
# 26      cumberlege crescent  04 66543416
# 27             binns street  07 78966507
# 28            bonney street  08 68844768
# 29         cuthbert circuit  04 07383833
# ...                     ...          ...
# 8882           golden grove            0
# 8883           melba street  08 65451564
# 8884  charterisville avenue  02 50042458
# 8885    phillipson crescent  03 40648363
# 8886        hatfield street  04 26020969
# 8887        dirrawan garden  02 26723870
# 8888           gosse street            0
# 8889          cowper street  04 79403053
# 8890        maclagan street  04 60018297
# 8891         doolette place  02 25475709
# 8892          wisdom street  07 73677916
# 8893       blackburn street  08 48177167
# 8894            zox circuit  07 52848763
# 8895        aspinall street  03 10574555
# 8896             read place  03 39590322
# 8897            pring place  03 34262498
# 8898         harford street  07 68837484
# 8899     maclaurin crescent  08 60779502
# 8900         ainslie avenue  03 04392948
# 8901    tattersall crescent  04 73236430
# 8902          oliver street  04 06504891
# 8903           humble court  07 94462550
# 8904       macgregor street  02 48970596
# 8905          mullins place  08 26880272
# 8906           boote street  03 49081529
# 8907             leal place            0
# 8908     ratcliffe crescent  02 19648886
# 8909            orion place  07 63878836
# 8910        pitcairn street  04 68103123
# 8911        sturgeon street  07 31607552
#
#                                      address_2  postcode_updated  \
# 0                                         None              4514
# 1                            ocean star villas              4551
# 2                                         None              3199
# 3                                         None              3280
# 4                                       talawa              2602
# 5                               woodberry vlge              2142
# 6                                     hopeview              2527
# 7                                         None              4224
# 8                                      cascina              3194
# 9                                    inglewood              3315
# 10                                        None              3089
# 11                                   glen eden              3125
# 12                                        None              3155
# 13               kangaroo ground warrandy road              4113
# 14                                        None              7315
# 15                                        None              4565
# 16                                    burnside              2750
# 17                                   musk park              2484
# 18                      enter boolwey s street              4506
# 19                                    lasswade              6155
# 20                                 riley house              2780
# 21                                  harrowvale              6281
# 22                                    watgania              4670
# 23                                        None              3754
# 24                                        None              5341
# 25                         castlereagh village              2142
# 26                                       lesma              6060
# 27                                    burraroo              2540
# 28                                        None              3012
# 29                                    braeburn              3233
# ...                                        ...               ...
# 8882                                      None              4217
# 8883                                      None              4740
# 8884                                      None              3195
# 8885                                fine-a-lea              3137
# 8886                                  meringle              4570
# 8887                                      None              4510
# 8888                                      None              2620
# 8889                                      None              6027
# 8890                                     wyuna              3977
# 8891                                      None              3036
# 8892                                  malahoff              4390
# 8893                        the denture centre              2132
# 8894                                  port 272              5583
# 8895                                      None              3136
# 8896                                      None              4113
# 8897                                      None              3023
# 8898                                      None               820
# 8899                                      None              2121
# 8900                                      None              2500
# 8901                                      None              5159
# 8902                                      None              2795
# 8903  twenty-third avenue pharmacy (cnr mawarr              3976
# 8904                               moulin view              2131
# 8905                          fairfield waters              2065
# 8906                                  bramhall              4670
# 8907                                   pangani              4670
# 8908                                      None              2170
# 8909                               silverpoint              3429
# 8910                                  waratana              3224
# 8911                                   villa 5              5244
#
#      state_updated    suburb_updated  dob_updated  age_final
# 0              qld        north ward         1973         47
# 1              qld         swan view         1990         30
# 2              vic     bribie island         1943         77
# 3              vic          carnegie         1954         66
# 4              act   south melbourne         1975         45
# 5              nsw           torquay         1918        102
# 6              nsw           mentone         1938         82
# 7              qld           toowong         1961         59
# 8              vic         bayswater         2007         13
# 9              vic          hamilton         1930         90
# 10             vic          lockleys         1960         60
# 11             vic         frankston         2001         19
# 12             vic           belmont         2011          9
# 13             qld          cronulla         1991         29
# 14             tas           ivanhoe         1996         24
# 15             qld        canterbury         1920        100
# 16             nsw  bolwarra heights         1984         36
# 17             nsw     oakleigh east         1963         57
# 18             qld           berwick         1988         32
# 19              wa         bar beach         1925         95
# 20             nsw        paddington         1929         91
# 21              wa  chain valley bay         1900        120
# 22             qld          kirrawee         1979         41
# 23             vic             bluff         1939         81
# 24              sa         punchbowl         1919        101
# 25             nsw     rawdon island         1940         80
# 26              wa      tallebudgera         1976         44
# 27             nsw     kilsyth south         1987         33
# 28             vic          carnegie         1938         82
# 29             vic              como         1985         35
# ...            ...               ...          ...        ...
# 8882           qld         toowoomba         1949         71
# 8883           qld            burnie         1902        118
# 8884           vic     campbellfield         1924         96
# 8885           vic          parkdale         1998         22
# 8886           qld        myrtleford         1965         55
# 8887           qld      malvern east         1948         72
# 8888           nsw          hawthorn         1905        115
# 8889            wa         peakhurst         1982         38
# 8890           vic          kardinya         1993         27
# 8891           vic         mount isa         1932         88
# 8892           qld             cooma         1946         74
# 8893           nsw     berkeley vale         1960         60
# 8894            sa          st clair         1955         65
# 8895           vic            orbost         1962         58
# 8896           qld          labrador         1992         28
# 8897           vic          carnegie         1965         55
# 8898            nt      melton south         1919        101
# 8899           nsw       normanhurst         1975         45
# 8900           nsw         frankston         1905        115
# 8901            sa          watsonia         1965         55
# 8902           nsw      campbelltown         1917        103
# 8903           vic      glenel south         1944         76
# 8904           nsw      skenes creek         1919        101
# 8905           nsw           mentone         1913        107
# 8906           qld        mirrabooka         1918        102
# 8907           qld       forest hill         1976         44
# 8908           nsw       lamb island         1984         36
# 8909           vic          beecroft         1909        111
# 8910           vic        manly vale         1993         27
# 8911            sa            baxter         1918        102
#
# [8912 rows x 13 columns]

# %%
#Export dataframe to csv
#df_pcr_clean.to_csv('df_patient_pcr_clean.csv',index=False)
